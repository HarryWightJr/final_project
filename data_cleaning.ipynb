# %% [markdown]
# <a href="https://colab.research.google.com/github/HarryWightJr/final_project/blob/zsloan1/data_cleaning.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Add the Pandas dependency.
import pandas as pd
import os

# %%
# Files to load
crime_2019 = "https://bootcamp-project.s3.amazonaws.com/Crime_2019.csv"
crime_2020 = "https://bootcamp-project.s3.amazonaws.com/Crime_2019.csv"
city_sales = "https://bootcamp-project.s3.amazonaws.com/Sale_Prices_City.csv"
income = "https://bootcamp-project.s3.amazonaws.com/Income.csv"

# %%
crime_2019_df = pd.read_csv(crime_2019)
crime_2020_df = pd.read_csv(crime_2020)
city_sales_df = pd.read_csv(city_sales)
income_df = pd.read_csv(income)

# %%
crime_2019_df.head()
# Out:
#         City    State City and State  CountyID  Population 2019  \
# 0     Hoover  ALABAMA     Hoover, AL      1073          85670.0
# 1  Anchorage   ALASKA  Anchorage, AK      2020         287731.0
# 2     Bethel   ALASKA     Bethel, AK      2050           6544.0
# 3    Cordova   ALASKA    Cordova, AK      2261           2150.0
# 4      Craig   ALASKA      Craig, AK      2198           1313.0
#
#    Violent Crime Total 2019  Property Crime Total 2019
# 0                     114.0                     1922.0
# 1                    3581.0                    12261.0
# 2                     130.0                      132.0
# 3                       0.0                        7.0
# 4                       7.0                       20.0

# %%
dropped_crime_2019_df = crime_2019_df.drop(columns=["City", "State","City and State"])
sorted_crime_2019_df = dropped_crime_2019_df.sort_values("Population 2019")
final_crime_2019_df = sorted_crime_2019_df.drop_duplicates(subset=['CountyID'], keep='last')
final_crime_2019_df.head()
# Out:
#       CountyID  Population 2019  Violent Crime Total 2019  \
# 3387     29199            111.0                       0.0
# 724       8047            128.0                       8.0
# 4135     38007            130.0                       0.0
# 4141     38013            279.0                       0.0
# 2401     22037            295.0                       0.0
#
#       Property Crime Total 2019
# 3387                        0.0
# 724                       211.0
# 4135                        0.0
# 4141                        0.0
# 2401                        0.0

# %%
final_crime_2019_df.count()
# Out:
# CountyID                     2153
# Population 2019              2152
# Violent Crime Total 2019     2140
# Property Crime Total 2019    2141
# dtype: int64

# %%
crime_2020_df.head()
# Out:
#         City    State City and State  CountyID  Population 2019  \
# 0     Hoover  ALABAMA     Hoover, AL      1073          85670.0
# 1  Anchorage   ALASKA  Anchorage, AK      2020         287731.0
# 2     Bethel   ALASKA     Bethel, AK      2050           6544.0
# 3    Cordova   ALASKA    Cordova, AK      2261           2150.0
# 4      Craig   ALASKA      Craig, AK      2198           1313.0
#
#    Violent Crime Total 2019  Property Crime Total 2019
# 0                     114.0                     1922.0
# 1                    3581.0                    12261.0
# 2                     130.0                      132.0
# 3                       0.0                        7.0
# 4                       7.0                       20.0

# %%
dropped_crime_2020_df = crime_2020_df.drop(columns=["City", "State","City and State"])
sorted_crime_2020_df = dropped_crime_2020_df.sort_values("Population 2020")
final_crime_2020_df = sorted_crime_2020_df.drop_duplicates(subset=['CountyID'], keep='last')
final_crime_2020_df.head()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-10-b0fed348cb69> in <module>()
#       1 dropped_crime_2020_df = crime_2020_df.drop(columns=["City", "State","City and State"])
# ----> 2 sorted_crime_2020_df = dropped_crime_2020_df.sort_values("Population 2020")
#       3 final_crime_2020_df = sorted_crime_2020_df.drop_duplicates(subset=['CountyID'], keep='last')
#       4 final_crime_2020_df.head()
#
# /usr/local/lib/python3.7/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py in sort_values(self, by, axis, ascending, inplace, kind, na_position, ignore_index, key)
#    6257
#    6258             by = by[0]
# ...

# %%
final_crime_2020_df.count()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-11-4d422f5552db> in <module>()
# ----> 1 final_crime_2020_df.count()
#
# NameError: name 'final_crime_2020_df' is not defined

# %%
city_sales_df.head()
# Out:
#           RegionName   StateName  CountyID  AverageSalesPrice2019  \
# 0     Youngstown, OH        Ohio   39099.0                29625.0
# 1         Harvey, IL    Illinois   17031.0                35183.0
# 2        Trenton, NJ  New Jersey   34021.0                51833.0
# 3  Maple Heights, OH        Ohio   39035.0                58692.0
# 4       Bay City, MI    Michigan   26017.0                59150.0
#
#    AverageSalesPrice2020
# 0                31300.0
# 1                36000.0
# 2                56450.0
# 3                70567.0
# 4                64300.0

# %%
dropped_city_sales_df = city_sales_df.drop(columns=["RegionName", "StateName"])
final_city_sales_df = dropped_city_sales_df.drop_duplicates(subset=['CountyID'], keep='last')
final_city_sales_df.head()
# Out:
#     CountyID  AverageSalesPrice2019  AverageSalesPrice2020
# 4    26017.0                59150.0                64300.0
# 12   17115.0                73833.0                86450.0
# 13   17095.0                75767.0                68850.0
# 14    5069.0                76300.0                76967.0
# 16   19179.0                77258.0                68800.0

# %%
final_city_sales_df.count()
# Out:
# CountyID                 994
# AverageSalesPrice2019    994
# AverageSalesPrice2020    994
# dtype: int64

# %%
income_df.head()
# Out:
#     County    State     County, State  CountyID  Income_2019  Income_2020
# 0  Autauga  Alabama  Autauga, Alabama      1001        44368        46814
# 1  Baldwin  Alabama  Baldwin, Alabama      1003        48270        50953
# 2  Barbour  Alabama  Barbour, Alabama      1005        35572        37850
# 3     Bibb  Alabama     Bibb, Alabama      1007        31540        34300
# 4   Blount  Alabama   Blount, Alabama      1009        36969        38808

# %%
dropped_income_df = income_df.drop(columns=["County", "State","County, State"])
final_income_df = dropped_income_df.drop_duplicates(subset=['CountyID'], keep='last')
final_income_df.head()
# Out:
#    CountyID  Income_2019  Income_2020
# 0      1001        44368        46814
# 1      1003        48270        50953
# 2      1005        35572        37850
# 3      1007        31540        34300
# 4      1009        36969        38808

# %%
final_income_df.count()
# Out:
# CountyID       3038
# Income_2019    3038
# Income_2020    3038
# dtype: int64

# %%
# Combine the data into a single dataset.
partial_1_df = pd.merge(final_city_sales_df, final_crime_2019_df, how="left", on=["CountyID"])
partial_1_df.head()
# Out:
#    CountyID  AverageSalesPrice2019    AverageSalesPrice2020  Population 2019  \
# 0     26017                    59150                  64300          32793.0
# 1     17115                    73833                  86450          70710.0
# 2     17095                    75767                  68850          30220.0
# 3      5069                    76300                  76967          41505.0
# 4     19179                    77258                  68800          24488.0
#
#    Violent Crime Total 2019  Property Crime Total 2019
# 0                     271.0                      654.0
# 1                     375.0                     1954.0
# 2                     138.0                     1249.0
# 3                     644.0                        NaN
# 4                     134.0                     1009.0

# %%
partial_2_df = pd.merge(partial_1_df, final_crime_2020_df, how="left", on=["CountyID"])
partial_2_df.head()
# Out:
#    CountyID  AverageSalesPrice2019    AverageSalesPrice2020  Population 2019  \
# 0     26017                    59150                  64300          32793.0
# 1     17115                    73833                  86450          70710.0
# 2     17095                    75767                  68850          30220.0
# 3      5069                    76300                  76967          41505.0
# 4     19179                    77258                  68800          24488.0
#
#    Violent Crime Total 2019  Property Crime Total 2019  Population 2020  \
# 0                     271.0                      654.0          32485.0
# 1                     375.0                     1954.0          70175.0
# 2                     138.0                     1249.0          29985.0
# 3                     644.0                        NaN          40718.0
# 4                     134.0                     1009.0          24293.0
#
#    Violent Crime Total 2020  Property Crime Total 2020
# ...

# %%
complete_df = pd.merge(partial_2_df, final_income_df, how="left", on=["CountyID"])
complete_df.head()
# Out:
#    CountyID  AverageSalesPrice2019    AverageSalesPrice2020  Population 2019  \
# 0     26017                    59150                  64300          32793.0
# 1     17115                    73833                  86450          70710.0
# 2     17095                    75767                  68850          30220.0
# 3      5069                    76300                  76967          41505.0
# 4     19179                    77258                  68800          24488.0
#
#    Violent Crime Total 2019  Property Crime Total 2019  Population 2020  \
# 0                     271.0                      654.0          32485.0
# 1                     375.0                     1954.0          70175.0
# 2                     138.0                     1249.0          29985.0
# 3                     644.0                        NaN          40718.0
# 4                     134.0                     1009.0          24293.0
#
# ...

# %%
complete_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 994 entries, 0 to 993
# Data columns (total 11 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   CountyID                   994 non-null    int64
#  1   AverageSalesPrice2019      994 non-null    int64
#  2   AverageSalesPrice2020      994 non-null    int64
#  3   Population 2019            887 non-null    float64
#  4   Violent Crime Total 2019   883 non-null    float64
#  5   Property Crime Total 2019  880 non-null    float64
#  6   Population 2020            873 non-null    float64
#  7   Violent Crime Total 2020   872 non-null    float64
#  8   Property Crime Total 2020  844 non-null    float64
#  9   Income_2019                961 non-null    float64
#  10  Income_2020                961 non-null    float64
# dtypes: float64(8), int64(3)
# memory usage: 93.2 KB

# %%
complete_df.isna()
# Out:
#      CountyID  AverageSalesPrice2019    AverageSalesPrice2020  \
# 0       False                    False                  False
# 1       False                    False                  False
# 2       False                    False                  False
# 3       False                    False                  False
# 4       False                    False                  False
# ..        ...                      ...                    ...
# 989     False                    False                  False
# 990     False                    False                  False
# 991     False                    False                  False
# 992     False                    False                  False
# 993     False                    False                  False
#
#      Population 2019  Violent Crime Total 2019  Property Crime Total 2019  \
# 0              False                     False                      False
# ...

# %%
complete_df = complete_df.dropna(subset = ['Population 2019', 'Violent Crime Total 2019', 'Property Crime Total 2019','Population 2020', 'Violent Crime Total 2020', 'Property Crime Total 2020', 'Income_2019', 'Income_2020'])

# %%
complete_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 764 entries, 0 to 993
# Data columns (total 11 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   CountyID                   764 non-null    int64
#  1   AverageSalesPrice2019      764 non-null    int64
#  2   AverageSalesPrice2020      764 non-null    int64
#  3   Population 2019            764 non-null    float64
#  4   Violent Crime Total 2019   764 non-null    float64
#  5   Property Crime Total 2019  764 non-null    float64
#  6   Population 2020            764 non-null    float64
#  7   Violent Crime Total 2020   764 non-null    float64
#  8   Property Crime Total 2020  764 non-null    float64
#  9   Income_2019                764 non-null    float64
#  10  Income_2020                764 non-null    float64
# dtypes: float64(8), int64(3)
# memory usage: 71.6 KB

# %%
complete_df.to_csv('Resources/complete_df.csv')

# %%
# Find the latest version of spark 3.0 from http://www.apache.org/dist/spark/ and enter as the spark version
# For example:
# spark_version = 'spark-3.0.3'
spark_version = 'spark-3.0.3'
os.environ['SPARK_VERSION']=spark_version

# Install Spark and Java
# !apt-get update
# !apt-get install openjdk-11-jdk-headless -qq > /dev/null
# !wget -q http://www.apache.org/dist/spark/$SPARK_VERSION/$SPARK_VERSION-bin-hadoop2.7.tgz
# !tar xf $SPARK_VERSION-bin-hadoop2.7.tgz
# !pip install -q findspark

# Set Environment Variables
import os
os.environ["JAVA_HOME"] = "/usr/lib/jvm/java-11-openjdk-amd64"
os.environ["SPARK_HOME"] = f"/content/{spark_version}-bin-hadoop2.7"

# Start a SparkSession
import findspark
findspark.init()
# Out:
# Ign:1 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  InRelease
# Ign:2 https://developer.download.nvidia.com/compute/machine-learning/repos/ubuntu1804/x86_64  InRelease
# Get:3 https://cloud.r-project.org/bin/linux/ubuntu bionic-cran40/ InRelease [3,626 B]
# Get:4 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  Release [696 B]
# Hit:5 https://developer.download.nvidia.com/compute/machine-learning/repos/ubuntu1804/x86_64  Release
# Get:6 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  Release.gpg [836 B]
# Hit:7 http://archive.ubuntu.com/ubuntu bionic InRelease
# Get:8 http://archive.ubuntu.com/ubuntu bionic-updates InRelease [88.7 kB]
# Get:9 http://security.ubuntu.com/ubuntu bionic-security InRelease [88.7 kB]
# Get:10 https://cloud.r-project.org/bin/linux/ubuntu bionic-cran40/ Packages [80.4 kB]
# Get:11 http://ppa.launchpad.net/c2d4u.team/c2d4u4.0+/ubuntu bionic InRelease [15.9 kB]
# ...

# %%
# Start Spark session
from pyspark.sql import SparkSession
spark = SparkSession.builder.appName("DataFrameBasics").getOrCreate()

# %%
# !wget https://jdbc.postgresql.org/download/postgresql-42.2.16.jar
# Out:
# --2022-03-20 23:31:53--  https://jdbc.postgresql.org/download/postgresql-42.2.16.jar
# Resolving jdbc.postgresql.org (jdbc.postgresql.org)... 72.32.157.228, 2001:4800:3e1:1::228
# Connecting to jdbc.postgresql.org (jdbc.postgresql.org)|72.32.157.228|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1002883 (979K) [application/java-archive]
# Saving to: ‘postgresql-42.2.16.jar’
#
# postgresql-42.2.16. 100%[===================>] 979.38K  5.92MB/s    in 0.2s
#
# 2022-03-20 23:31:54 (5.92 MB/s) - ‘postgresql-42.2.16.jar’ saved [1002883/1002883]

# %%
from pyspark.sql import SparkSession
spark = SparkSession.builder.appName("CloudETL").config("spark.driver.extraClassPath","/content/postgresql-42.2.16.jar").getOrCreate()

# %%
# Read in data from S3 Buckets
from pyspark import SparkFiles
url = "https://bootcamp-project.s3.amazonaws.com/complete_df.csv"
spark.sparkContext.addFile(url)
df = spark.read.csv(SparkFiles.get("complete_df.csv"), sep=",", header=True)

# %%
# show DataFrame
df.show()
# Out:
# +---+--------+-------------------------+-----------------------+---------------+------------------------+-----------------------------------------+---------+------------+-----------------------+-------------------------+-------------+------------------+------------------------+----------+---------------+------------------------+-----------------------------------------+---------+------------+-----------------------+-------------------------+-------------+------------------+------------------------+----------+-----------+-----------+
# ...

# %%
# Print our schema
df.printSchema()
# Out:
# root
#  |-- _c0: string (nullable = true)
#  |-- CountyID: string (nullable = true)
#  |--   AverageSalesPrice2019  : string (nullable = true)
#  |--   AverageSalesPrice2020: string (nullable = true)
#  |-- Population 2019: string (nullable = true)
#  |-- Violent Crime Total 2019: string (nullable = true)
#  |-- Murder and nonnegligent manslaughter 2019: string (nullable = true)
#  |-- Rape 2019: string (nullable = true)
#  |-- Robbery 2019: string (nullable = true)
#  |-- Aggravated assault 2019: string (nullable = true)
#  |-- Property Crime Total 2019: string (nullable = true)
#  |-- Burglary 2019: string (nullable = true)
#  |-- Larceny-theft 2019: string (nullable = true)
#  |-- Motor vehicle theft 2019: string (nullable = true)
#  |-- Arson 2019: string (nullable = true)
#  |-- Population 2020: string (nullable = true)
#  |-- Violent Crime Total 2020: string (nullable = true)
#  |-- Murder and nonnegligent manslaughter 2020: string (nullable = true)
# ...

# %%
# Import struct fields that we can use
from pyspark.sql.types import StructField, StringType, IntegerType, StructType

# %%
# Next we need to create the list of struct fields
schema = [StructField("crime", StringType(), True), StructField("price", IntegerType(), True),]
schema
# Out:
# [StructField(crime,StringType,true), StructField(price,IntegerType,true)]

# %%
# Store environmental variable
from getpass import getpass
password = getpass('Enter database password')
# Configure settings for RDS
mode = "append"
jdbc_url="jdbc:postgresql://database-1.cx6o5jgyfq1i.us-east-1.rds.amazonaws.com:5432/database-1"
config = {"user":"postgres",
          "password": "bootcamp",
          "driver":"org.postgresql.Driver"}
# Out:
# Enter database password··········
